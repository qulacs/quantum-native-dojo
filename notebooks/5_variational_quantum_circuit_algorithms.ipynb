# %% [markdown]
# # 第5章 変分量子回路に基づくアルゴリズム
#
# この章では、NISQ 時代を代表する変分量子アルゴリズムを扱う。VQE、QCL、QAOA を軸にしつつ、書籍版のコラム構成へ寄せて再編する。

# %% [markdown]
# ## 章構成（予定）
#
# - 5-1. 変分量子固有値ソルバー（VQE）アルゴリズム
# - 5-2. 量子回路学習（QCL）アルゴリズム
# - 5-3. 量子近似最適化アルゴリズム（QAOA）
# - コラム: エネルギー期待値の測定法とその統計的ゆらぎ
# - コラム: 不毛な台地
# - コラム: 量子アニーリング

# %% [markdown]
# ## 移行メモ
#
# 5-1, 5-2, 5-3 は現行 notebook を土台に再編集できる可能性が高い。一方で、現行コラムの整理方針は別途決める。
