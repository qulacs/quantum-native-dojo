# %% [markdown]
# # 第2章 量子アルゴリズム入門
#
# この章では、量子アルゴリズムの考え方を初歩から学び、量子位相推定へつながる基本技法を扱う。現行サイトの骨格を活かしつつ、書籍版のコラム構成に寄せていく。

# %% [markdown]
# ## 章構成（予定）
#
# - 2-1. 量子アルゴリズムの分類
# - 2-2. アダマールテスト
# - 2-3. 量子フーリエ変換
# - 2-4. 量子位相推定アルゴリズムの基礎
# - コラム: Quantum Algorithm Zoo
# - コラム: 計算量のオーダー記法
# - コラム: 計算量について
# - コラム: 量子位相推定アルゴリズムの計算量と量子加速

# %% [markdown]
# ## 移行メモ
#
# この章は既存 notebook から流用しやすいが、コラムの切り出しと導入文の更新が必要になる。節 notebook の準備後に `toctree` を追加する。
