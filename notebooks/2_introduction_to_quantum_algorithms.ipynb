# %% [markdown]
# # 第2章 量子アルゴリズム入門
#
# 量子コンピュータは，量子力学的な重ね合わせによって，n 個の量子ビットを用いて 2^n 個の状態を同時に処理できる．しかし，これだけでは「計算が速い」ということにはならない．なぜなら，計算終了後に結果を観測する際に，2^n 個の状態のうちのどれか 1 つがランダムに得られるのみだからである．したがって，欲しい答えが高確率で得られるように設計された，量子コンピュータに特化したアルゴリズムが不可欠である．そのようなアルゴリズムを量子アルゴリズムと呼ぶ．量子アルゴリズムの有名な例として，ショアの素因数分解アルゴリズム，グローバーの探索アルゴリズムがある．
#
# 本章では，量子アルゴリズムの初歩から始めて，最後に最も重要な量子アルゴリズムの 1 つである量子位相推定アルゴリズムを学ぶ．まず 2.1 節で，量子アルゴリズムのおおまかな概観や便宜上の分類について解説する．次に，2.2 節でアダマールテストという最も簡単な量子アルゴリズムを学び，量子フーリエ変換（2.3 節），量子位相推定アルゴリズム（2.4 節）と徐々に高度なアルゴリズムを学んでいく．本章で習う量子フーリエ変換と量子位相推定アルゴリズムは量子コンピュータを活用するうえで非常に大切であり，しっかりと身につけてほしい．

# %% [markdown]
# - [2-1. 量子アルゴリズムの分類](2.1_classification_of_quantum_algorithms.ipynb)
# - [2-2. アダマールテスト](2.2_hadamard_test.ipynb)
# - [2-3. 量子フーリエ変換](2.3_quantum_fourier_transform.ipynb)
# - [2-4. 量子位相推定アルゴリズムの基礎](2.4_basics_of_quantum_phase_estimation.ipynb)

# %% [markdown]
# - [コラム: Quantum Algorithm Zoo](2.c1_quantum_algorithm_zoo.ipynb)
# - [コラム: 計算量のオーダー記法](2.c2_big_o_notation.ipynb)
# - [コラム: 計算量について](2.c3_computational_complexity.ipynb)
# - [コラム: 量子位相推定アルゴリズムの計算量と量子加速](2.c4_qpe_complexity_and_quantum_speedup.ipynb)
