# %% [markdown]
# # 第7章 量子位相推定アルゴリズムの応用
#
# この章では、量子位相推定の応用先として、反復的位相推定、ショアのアルゴリズム、HHL アルゴリズムを扱う。現行の HHL 中心の構成から大きく再編する。

# %% [markdown]
# - [7-1. 反復的量子位相推定アルゴリズム](7.1_iterative_quantum_phase_estimation.ipynb)
# - [7-2. ショアのアルゴリズム（素因数分解）](7.2_shors_algorithm.ipynb)
# - [7-3. HHL アルゴリズムを用いた連立一次方程式の解法](7.3_hhl_algorithm_for_linear_systems.ipynb)

# %% [markdown]
# - [コラム: 量子位相推定における補助ビットの削減手法](7.c1_auxiliary_qubit_reduction_in_qpe.ipynb)
# - [コラム: 古典計算を行う量子回路と量子算術演算](7.c2_quantum_circuits_for_classical_computation_and_quantum_arithmetic.ipynb)
# - [コラム: 量子ランダムアクセスメモリ（QRAM）](7.c3_qram.ipynb)
