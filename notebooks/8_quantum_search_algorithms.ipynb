# %% [markdown]
# # 第8章 量子探索アルゴリズム
#
# この章では、オラクル、グローバー探索、量子振幅増幅・量子振幅推定を扱う。現行の第8章を土台にしつつ、書籍版の 8-3 とコラムを追加する。

# %% [markdown]
# ## 章構成（予定）
#
# - 8-1. オラクル
# - 8-2. グローバーのアルゴリズム
# - 8-3. 量子振幅増幅（QAA）アルゴリズムと量子振幅推定（QAE）アルゴリズム
# - コラム: Fixed-point グローバーアルゴリズム
# - コラム: 二次加速を実現する量子アルゴリズムの有用性

# %% [markdown]
# ## 移行メモ
#
# 8-1, 8-2 は既存 notebook から再編集しやすい。8-3 は新設とし、章トップは先に新名称へ更新する。
