# %% [markdown]
# # 第8章 量子探索アルゴリズム
#
# この章では、オラクル、グローバー探索、量子振幅増幅・量子振幅推定を扱う。現行の第8章を土台にしつつ、書籍版の 8-3 とコラムを追加する。

# %% [markdown]
# - [8-1. オラクル](8.1_oracles.ipynb)
# - [8-2. グローバーのアルゴリズム](8.2_grovers_algorithm.ipynb)
# - [8-3. 量子振幅増幅（QAA）アルゴリズムと量子振幅推定（QAE）アルゴリズム](8.3_qaa_and_qae.ipynb)

# %% [markdown]
# - [コラム: Fixed-point グローバーアルゴリズム](8.c1_fixed_point_grover.ipynb)
# - [コラム: 二次加速を実現する量子アルゴリズムの有用性](8.c2_usefulness_of_quadratic_speedup.ipynb)
