# %% [markdown]
# # 第4章 量子ダイナミクスシミュレーション
#
# この章では、量子系の時間発展をシミュレーションする考え方と、その実装方法を学ぶ。既存の 4-1, 4-2 を見直しつつ、書籍版で追加された 4-3 を含めて再構成する。

# %% [markdown]
# ## 章構成（予定）
#
# - 4-1. ダイナミクス（時間発展）とは
# - 4-2. トロッター分解を用いた量子ダイナミクスシミュレーション
# - 4-3. その他の量子ダイナミクスシミュレーション

# %% [markdown]
# ## 移行メモ
#
# 4-1, 4-2 には既存資産の流用余地がある。4-3 は新設とし、章トップは書籍版の章説明に合わせて置き換える。
