# %% [markdown]
# # 第3章 量子アルゴリズムの実行環境: QURI Parts を用いたプログラミング
#
# この章では、量子アルゴリズムを実装・検証するための実行環境として QURI Parts を扱う。現行の Qulacs / Qiskit 中心の章から全面的に再編する章である。

# %% [markdown]
# ## 章構成（予定）
#
# - 3-1. QURI Parts とは
# - 3-2. 応用例: ベル不等式（CHSH 不等式）の破れのシミュレーション

# %% [markdown]
# ## 移行メモ
#
# この章は新規作成が前提。旧第3章 notebook は `obsolete/chapter_tops/` に退避済みで、節 notebook も新規に切る想定とする。
