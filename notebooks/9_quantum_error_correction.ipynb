# %% [markdown]
# # 第9章 量子誤り訂正
#
# この章では、量子誤り訂正の基礎から誤り耐性量子計算、表面符号までを体系的に扱う。現行の2節構成では足りないため、書籍版に合わせて大幅に拡張する。

# %% [markdown]
# ## 節

# %% [markdown]
# - [9-1. 量子誤り訂正とは](9.1_introduction_to_quantum_error_correction.ipynb)
# - [9-2. 量子力学におけるノイズの記述法](9.2_noise_models_in_quantum_mechanics.ipynb)
# - [9-3. 量子誤り訂正符号の基礎](9.3_basics_of_quantum_error_correcting_codes.ipynb)
# - [9-4. スタビライザー形式とスタビライザー符号](9.4_stabilizer_formalism_and_codes.ipynb)
# - [9-5. 誤り耐性量子計算](9.5_fault_tolerant_quantum_computing.ipynb)
# - [9-6. 表面符号](9.6_surface_codes.ipynb)

# %% [markdown]
# ## コラム

# %% [markdown]
# - [コラム: NISQ と量子誤り抑制（QEM）](9.c1_nisq_and_quantum_error_mitigation.ipynb)
# - [コラム: 理論モデルと実機の性能指標（T1, T2）](9.c2_physical_metrics_t1_t2.ipynb)
# - [コラム: エラーの離散化](9.c3_discretization_of_errors.ipynb)
# - [コラム: ゴッテスマン–ニルの定理と量子計算の優位性](9.c4_gottesman_knill_and_quantum_advantage.ipynb)
# - [コラム: 測定型量子計算（MBQC）と誤り耐性量子計算](9.c5_mbqc_and_fault_tolerant_quantum_computing.ipynb)
# - [コラム: 量子 LDPC 符号](9.c6_quantum_ldpc_codes.ipynb)
