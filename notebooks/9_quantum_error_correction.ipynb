# %% [markdown]
# # 第9章 量子誤り訂正
#
# この章では、量子誤り訂正の基礎から誤り耐性量子計算、表面符号までを体系的に扱う。現行の2節構成では足りないため、書籍版に合わせて大幅に拡張する。

# %% [markdown]
# ## 章構成（予定）
#
# - 9-1. 量子誤り訂正とは
# - 9-2. 量子力学におけるノイズの記述法
# - 9-3. 量子誤り訂正符号の基礎
# - 9-4. スタビライザー形式とスタビライザー符号
# - 9-5. 誤り耐性量子計算
# - 9-6. 表面符号
# - コラム: NISQ と量子誤り抑制（QEM）
# - コラム: 理論モデルと実機の性能指標（T1, T2）
# - コラム: エラーの離散化
# - コラム: ゴッテスマン–ニルの定理と量子計算の優位性
# - コラム: 測定型量子計算（MBQC）と誤り耐性量子計算
# - コラム: 量子 LDPC 符号

# %% [markdown]
# ## 移行メモ
#
# この章は全面的に新規構成へ移行する。節 notebook が揃うまで章トップでは構成案のみを示し、後続で `toctree` を追加する。
