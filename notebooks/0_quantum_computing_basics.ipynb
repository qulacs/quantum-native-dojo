# %% [markdown]
# # 第0章 量子コンピュータの基礎知識
#
# この章では、量子コンピュータの全体像をつかむための導入を扱う。書籍版の構成に合わせて、量子コンピュータの基本概念、歴史的背景、代表的なハードウェア方式を順に整理する。

# %% [markdown]
# ## 節

# %% [markdown]
# - [0-1. 量子コンピュータとは](0.1_what_is_quantum_computing.ipynb)
# - [0-2. 量子コンピュータ開発の歴史的背景](0.2_historical_background_of_quantum_computing.ipynb)
# - [0-3. 量子コンピュータの代表的な方式](0.3_hardware_platforms_for_quantum_computing.ipynb)
