# %% [markdown]
# # 第0章 量子コンピュータの基礎知識
#
# この章では、量子コンピュータの全体像をつかむための導入を扱う。書籍版の構成に合わせて、量子コンピュータの基本概念、歴史的背景、代表的なハードウェア方式を順に整理する。

# %% [markdown]
# ## 章構成（予定）
#
# - 0-1. 量子コンピュータとは
# - 0-2. 量子コンピュータ開発の歴史的背景
# - 0-3. 量子コンピュータの代表的な方式

# %% [markdown]
# ## 移行メモ
#
# 節 notebook の作成後、この章トップに `nbsphinx-toctree` を追加する。図は初回移行ではプレースホルダで扱う。
