# %% [markdown]
# # 第6章 NISQ アルゴリズムの量子化学計算への応用
#
# この章では、NISQ アルゴリズムを量子化学へ応用する流れを扱う。現行の OpenFermion / Qulacs / SS-VQE 構成から、書籍版の背景知識・VQE・QSCI へ組み替える。

# %% [markdown]
# ## 章構成（予定）
#
# - 6-1. 量子化学計算の背景知識
# - 6-2. 変分量子固有値ソルバー（VQE）の実装
# - 6-3. サンプリングを活用したアルゴリズム: QSCI
# - コラム: 分子軌道法と第二量子化

# %% [markdown]
# ## 移行メモ
#
# この章は構成変更が大きいため、新規 notebook の作成を前提とする。現行の 6-2, 6-3 は参照資産として活かしつつ、ファイル名は新方針に合わせる。
