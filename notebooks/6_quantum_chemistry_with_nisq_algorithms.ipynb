# %% [markdown]
# # 第6章 NISQ アルゴリズムの量子化学計算への応用
#
# この章では、NISQ アルゴリズムを量子化学へ応用する流れを扱う。現行の OpenFermion / Qulacs / SS-VQE 構成から、書籍版の背景知識・VQE・QSCI へ組み替える。

# %% [markdown]
# - [6-1. 量子化学計算の背景知識](6.1_background_of_quantum_chemistry.ipynb)
# - [6-2. 変分量子固有値ソルバー（VQE）の実装](6.2_implementation_of_vqe_for_quantum_chemistry.ipynb)
# - [6-3. サンプリングを活用したアルゴリズム: QSCI](6.3_qsci.ipynb)

# %% [markdown]
# - [コラム: 分子軌道法と第二量子化](6.c1_molecular_orbital_method_and_second_quantization.ipynb)
