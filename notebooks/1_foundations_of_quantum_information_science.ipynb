# %% [markdown]
# # 第1章 量子情報科学の基礎
#
# この章では、量子ビット、量子ゲート、複数量子ビット系、量子回路図といった量子計算の基礎を扱う。書籍版に合わせて、本文とコラムを分離しやすい章トップにする。

# %% [markdown]
# ## 章構成（予定）
#
# - 1-1. 1量子ビットの記述
# - 1-2. 1量子ビットに対する操作
# - 1-3. 複数量子ビットの記述と操作
# - 1-4. 量子回路図
# - コラム: ブロッホ球
# - コラム: 量子計算のユニバーサルゲートセット
# - コラム: 量子複製不可能定理

# %% [markdown]
# ## 移行メモ
#
# 既存の第1章資産は比較的流用しやすい。旧コラム notebook は必要に応じて分割し、新しいコラム notebook として再編する。
